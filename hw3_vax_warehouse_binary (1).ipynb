# %% [markdown]
# # Homework 3: Vaccine Warehouse Binary
#
# ###  Bus 36109 "Advanced Decision Modeling with Python", Don Eisenstein
# Don Eisenstein &copy; Copyright 2024, University of Chicago

# %% [markdown]
# ## Instructions
#
# A vaccine is being produced at different manufacturing Plants to be distributed across the country to various Hospitals. Vaccines must travel through Warehouses along the way to a Hospital.
#
# Vaccines are transported in units of cases.  The capacity of a plant is in units of cases per week.  Each Warehouse must process and ship all the cases it receives each week.  Each Warehouse has a capacity of cases it can process each week and a processing cost to process each case.  Each Warehouse also has a fixed weekly operating cost that is incurred if it processes any cases of vaccine.  If a Warehouse processes no vaccine then its fixed cost is not incurred (that is, we can close a warehouse down and not incur its fixed cost).
#
# Each Hospital has a demand for vaccine cases each week.  The supply of vaccine to a hospital must not exceed its demand.
#
# The transportation cost is \$1 per vaccine case traveling one unit of distance between plants and warehouses and between warehouses and hospitals.
#
# All facilites, distances and costs are described in an Airtable base.
#
# Each manufacturing Plant must ship as many doses as possible in an attempt to meet, but not exceed, Hospital demand.  A manufacturing Plant can ship vaccines to multiple Warehouses, a Warehouse can ship vaccines to multiple Hospitals, and a Hospital can receive vaccines from multiple Warehouses.
#
# Your code should be robust, that is, it should NOT make any assumptions about the total plant and warehouse capacities, or total hospital demands.
#
# Your model should find the optimal vaccine flows from Plants to Warehouses and Warehouses to Hospitals to minimize the weekly transportation, processing and operating costs, while sending as much vaccine as is feasibly possible.  And in doing so, determining which Warehouses are Open and which Closed.
#
# **IMPORTANT:** Model your flow of vaccine cases as a continuous variable.  That is, you can ship fractions of cases between facilities.
#
# **NOTE** No single variable carrying flow should include the ENTIRE path from a Plant through a Warehouse and into a Hospital.   That is, you must have a set of simple flow variables from Plants to Warehouses, and another set of simple flow variables from Warehouses to Hospitals.
#
# Follow the notebook to walk you through the solution in parts.  Insert your answer to each part into the notebook below the question for each part.   Turn in your completed notebook with all output visible.

# %% [markdown]
# # Your Solution
#
# Insert your answer to each part into this notebook

# %%
! pip install pyairtable
# Out:
# Requirement already satisfied: pyairtable in /usr/local/lib/python3.11/dist-packages (3.1.1)
# Requirement already satisfied: inflection in /usr/local/lib/python3.11/dist-packages (from pyairtable) (0.5.1)
# Requirement already satisfied: pydantic<3,>=2 in /usr/local/lib/python3.11/dist-packages (from pyairtable) (2.11.2)
# Requirement already satisfied: requests>=2.22.0 in /usr/local/lib/python3.11/dist-packages (from pyairtable) (2.32.3)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.11/dist-packages (from pyairtable) (4.13.1)
# Requirement already satisfied: urllib3>=1.26 in /usr/local/lib/python3.11/dist-packages (from pyairtable) (2.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=2->pyairtable) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=2->pyairtable) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=2->pyairtable) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.22.0->pyairtable) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.22.0->pyairtable) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.22.0->pyairtable) (2025.1.31)

# %%
! pip install pulp
# Out:
# Requirement already satisfied: pulp in /usr/local/lib/python3.11/dist-packages (3.1.1)

# %%
import pulp
from pulp import LpBinary
from pyairtable import Api
from pprint import pprint

# %%
AIRTABLE_API_TOKEN= "patvwCWqLLfjG2BBl.4407710f167dc945893b8d08cc262236311b59baf23106c522ad9138a7b4c2f6"

BASE_ID="appWITdHvwKWupWZR" # The ID for the HW3 data table -- don't change this

api = Api(AIRTABLE_API_TOKEN)

PLANT_TABLE_ID = 'plants'
WAREHOUSES_TABLE_ID = 'warehouses'
HOSPITALS_TABLE_ID = 'hospitals'
DISTANCE_TABLE_ID = 'distances'

plants_table = api.table(BASE_ID, PLANT_TABLE_ID)
warehouses_table = api.table(BASE_ID, WAREHOUSES_TABLE_ID)
hospitals_table = api.table(BASE_ID, HOSPITALS_TABLE_ID)
distances_table = api.table(BASE_ID, DISTANCE_TABLE_ID)

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# **1. In broad terms, what are the variables, objective and constraints of this problem? You don't need to list the entire formulation. Just describe the structure/characteristics of your model.**

# %% [markdown]
# Variables:
# There are several variables including:
#
# *   amount from plant to warehouse
# *   amount from warehouse to hospital
# *   demand of vaccines from hospital
# *   unit / transportation / distance / processing cost
#
#
#
# Constraints:
#
#
# *   Capacity of Each Plant
# *   Capacity of Each Warehouse
# *  Vaccines must flow from plant -> warehouse -> hospital
# * Can turn warehouses on and off

# %% [markdown]
# **2. Click on this link to access the data on AirTable: [AirTable Data](https://airtable.com/invite/l?inviteId=invCF2IEwn3KB68tR&inviteToken=8feebbc273e675e663a026e7a321221cedbdd4d893229610e2df40a2488647ef&utm_medium=email&utm_source=product_team&utm_content=transactional-alerts)**
#
# You may have to add access to this airtable base onto your token if you did not add permission to ALL bases to start.

# %% [markdown]
# <!-- END QUESTION -->
#
# **3. Read in the `plants` table from AirTable. Store in an appropriate structure in Python.  Print out your Python structure. Verify that the data looks as expected.**

# %%
plants = []

for plant in plants_table.all():
    plants.append(plant['fields'])

# %%
plants
# Out:
# [{'name': 'plant_6', 'capacity': 100},
#  {'name': 'plant_5', 'capacity': 100},
#  {'name': 'plant_2', 'capacity': 60},
#  {'name': 'plant_3', 'capacity': 150},
#  {'name': 'plant_1', 'capacity': 200},
#  {'name': 'plant_4', 'capacity': 40}]

# %% [markdown]
# **4.  Now read in, print, and verify the hospitals table.**

# %%
hospitals = []

for hospital in hospitals_table.all():
    hospitals.append(hospital['fields'])

# %%
hospitals
# Out:
# [{'name': 'hospital_2', 'demand': 40},
#  {'name': 'hospital_10', 'demand': 70},
#  {'name': 'hospital_6', 'demand': 90},
#  {'name': 'hospital_1', 'demand': 50},
#  {'name': 'hospital_4', 'demand': 120},
#  {'name': 'hospital_7', 'demand': 100},
#  {'name': 'hospital_5', 'demand': 50},
#  {'name': 'hospital_8', 'demand': 90},
#  {'name': 'hospital_9', 'demand': 50},
#  {'name': 'hospital_3', 'demand': 90}]

# %% [markdown]
# **5.  Now read in, print, and verify the warehouse table.**

# %%
warehouses = []

for warehouse in warehouses_table.all():
    warehouses.append(warehouse['fields'])

# %%
warehouses
# Out:
# [{'name': 'warehouse_8',
#   'capacity': 100,
#   'processing_cost': 10,
#   'fixed_cost': 550},
#  {'name': 'warehouse_5',
#   'capacity': 80,
#   'processing_cost': 25,
#   'fixed_cost': 1200},
#  {'name': 'warehouse_4',
#   'capacity': 100,
#   'processing_cost': 30,
#   'fixed_cost': 310},
#  {'name': 'warehouse_6',
#   'capacity': 290,
#   'processing_cost': 10,
#   'fixed_cost': 1590},
#  {'name': 'warehouse_3',
#   'capacity': 80,
#   'processing_cost': 30,
#   'fixed_cost': 290},
#  {'name': 'warehouse_7',
#   'capacity': 50,
#   'processing_cost': 25,
#   'fixed_cost': 410},
#  {'name': 'warehouse_2',
#   'capacity': 200,
#   'processing_cost': 25,
#   'fixed_cost': 750},
#  {'name': 'warehouse_1',
#   'capacity': 200,
#   'processing_cost': 20,
#   'fixed_cost': 1000}]

# %% [markdown]
# **6.  Now read in, print, and verify the distances table.**

# %%
distances = []

for distance in distances_table.all():
    distances.append(distance['fields'])

# %%
distances
# Out:
# [{'start': 'warehouse_5', 'end': 'hospital_3', 'distance': 284},
#  {'start': 'warehouse_3', 'end': 'hospital_9', 'distance': 269},
#  {'start': 'plant_2', 'end': 'warehouse_3', 'distance': 106},
#  {'start': 'plant_3', 'end': 'warehouse_6', 'distance': 70},
#  {'start': 'warehouse_5', 'end': 'hospital_5', 'distance': 213},
#  {'start': 'warehouse_7', 'end': 'hospital_5', 'distance': 228},
#  {'start': 'warehouse_4', 'end': 'hospital_1', 'distance': 364},
#  {'start': 'warehouse_5', 'end': 'hospital_9', 'distance': 209},
#  {'start': 'warehouse_6', 'end': 'hospital_4', 'distance': 125},
#  {'start': 'plant_6', 'end': 'warehouse_6', 'distance': 315},
#  {'start': 'plant_1', 'end': 'warehouse_6', 'distance': 177},
#  {'start': 'warehouse_4', 'end': 'hospital_3', 'distance': 191},
#  {'start': 'warehouse_7', 'end': 'hospital_6', 'distance': 110},
#  {'start': 'warehouse_8', 'end': 'hospital_4', 'distance': 121},
#  {'start': 'warehouse_3', 'end': 'hospital_2', 'distance': 10},
#  {'start': 'warehouse_6', 'end': 'hospital_10', 'distance': 229},
#  {'start': 'warehouse_3', 'end': 'hospital_7', 'distance': 206},
#  {'start': 'warehouse_8', 'end': 'hospital_3', 'distance': 275},
#  {'start': 'plant_2', 'end': 'warehouse_8', 'distance': 157},
#  {'start': 'plant_2', 'end': 'warehouse_5', 'distance': 166},
#  {'start': 'plant_1', 'end': 'warehouse_1', 'distance': 203},
#  {'start': 'warehouse_8', 'end': 'hospital_6', 'distance': 306},
#  {'start': 'plant_4', 'end': 'warehouse_3', 'distance': 13},
#  {'start': 'warehouse_7', 'end': 'hospital_4', 'distance': 205},
#  {'start': 'plant_4', 'end': 'warehouse_4', 'distance': 240},
#  {'start': 'plant_4', 'end': 'warehouse_2', 'distance': 111},
#  {'start': 'plant_2', 'end': 'warehouse_6', 'distance': 63},
#  {'start': 'warehouse_2', 'end': 'hospital_7', 'distance': 314},
#  {'start': 'warehouse_7', 'end': 'hospital_8', 'distance': 241},
#  {'start': 'warehouse_1', 'end': 'hospital_7', 'distance': 127},
#  {'start': 'warehouse_4', 'end': 'hospital_5', 'distance': 324},
#  {'start': 'warehouse_5', 'end': 'hospital_7', 'distance': 266},
#  {'start': 'warehouse_3', 'end': 'hospital_6', 'distance': 255},
#  {'start': 'warehouse_1', 'end': 'hospital_8', 'distance': 197},
#  {'start': 'warehouse_6', 'end': 'hospital_5', 'distance': 54},
#  {'start': 'warehouse_4', 'end': 'hospital_2', 'distance': 253},
#  {'start': 'warehouse_4', 'end': 'hospital_10', 'distance': 41},
#  {'start': 'warehouse_5', 'end': 'hospital_2', 'distance': 50},
#  {'start': 'plant_5', 'end': 'warehouse_4', 'distance': 246},
#  {'start': 'warehouse_6', 'end': 'hospital_9', 'distance': 438},
#  {'start': 'warehouse_8', 'end': 'hospital_2', 'distance': 73},
#  {'start': 'plant_6', 'end': 'warehouse_1', 'distance': 341},
#  {'start': 'warehouse_1', 'end': 'hospital_6', 'distance': 190},
#  {'start': 'warehouse_2', 'end': 'hospital_4', 'distance': 152},
#  {'start': 'warehouse_7', 'end': 'hospital_9', 'distance': 414},
#  {'start': 'plant_4', 'end': 'warehouse_8', 'distance': 60},
#  {'start': 'warehouse_3', 'end': 'hospital_8', 'distance': 96},
#  {'start': 'warehouse_4', 'end': 'hospital_9', 'distance': 302},
#  {'start': 'warehouse_3', 'end': 'hospital_3', 'distance': 224},
#  {'start': 'warehouse_1', 'end': 'hospital_3', 'distance': 141},
#  {'start': 'warehouse_5', 'end': 'hospital_10', 'distance': 186},
#  {'start': 'plant_3', 'end': 'warehouse_8', 'distance': 290},
#  {'start': 'warehouse_8', 'end': 'hospital_7', 'distance': 257},
#  {'start': 'warehouse_1', 'end': 'hospital_2', 'distance': 111},
#  {'start': 'plant_5', 'end': 'warehouse_2', 'distance': 105},
#  {'start': 'plant_6', 'end': 'warehouse_2', 'distance': 254},
#  {'start': 'plant_6', 'end': 'warehouse_5', 'distance': 272},
#  {'start': 'warehouse_2', 'end': 'hospital_2', 'distance': 98},
#  {'start': 'warehouse_6', 'end': 'hospital_1', 'distance': 114},
#  {'start': 'warehouse_1', 'end': 'hospital_10', 'distance': 255},
#  {'start': 'warehouse_3', 'end': 'hospital_5', 'distance': 153},
#  {'start': 'plant_1', 'end': 'warehouse_5', 'distance': 222},
#  {'start': 'plant_1', 'end': 'warehouse_8', 'distance': 213},
#  {'start': 'warehouse_7', 'end': 'hospital_3', 'distance': 79},
#  {'start': 'warehouse_8', 'end': 'hospital_1', 'distance': 184},
#  {'start': 'plant_3', 'end': 'warehouse_2', 'distance': 347},
#  {'start': 'warehouse_7', 'end': 'hospital_7', 'distance': 73},
#  {'start': 'warehouse_6', 'end': 'hospital_8', 'distance': 265},
#  {'start': 'plant_4', 'end': 'warehouse_7', 'distance': 144},
#  {'start': 'warehouse_4', 'end': 'hospital_7', 'distance': 173},
#  {'start': 'warehouse_2', 'end': 'hospital_1', 'distance': 163},
#  {'start': 'plant_2', 'end': 'warehouse_2', 'distance': 214},
#  {'start': 'plant_5', 'end': 'warehouse_7', 'distance': 358},
#  {'start': 'warehouse_7', 'end': 'hospital_1', 'distance': 268},
#  {'start': 'warehouse_6', 'end': 'hospital_6', 'distance': 164},
#  {'start': 'plant_1', 'end': 'warehouse_4', 'distance': 129},
#  {'start': 'warehouse_6', 'end': 'hospital_7', 'distance': 101},
#  {'start': 'warehouse_4', 'end': 'hospital_6', 'distance': 222},
#  {'start': 'plant_4', 'end': 'warehouse_1', 'distance': 98},
#  {'start': 'plant_3', 'end': 'warehouse_1', 'distance': 138},
#  {'start': 'plant_1', 'end': 'warehouse_7', 'distance': 17},
#  {'start': 'plant_5', 'end': 'warehouse_1', 'distance': 314},
#  {'start': 'warehouse_2', 'end': 'hospital_5', 'distance': 261},
#  {'start': 'warehouse_4', 'end': 'hospital_8', 'distance': 199},
#  {'start': 'plant_1', 'end': 'warehouse_2', 'distance': 270},
#  {'start': 'plant_4', 'end': 'warehouse_5', 'distance': 63},
#  {'start': 'plant_6', 'end': 'warehouse_4', 'distance': 49},
#  {'start': 'warehouse_5', 'end': 'hospital_8', 'distance': 36},
#  {'start': 'plant_5', 'end': 'warehouse_3', 'distance': 213},
#  {'start': 'warehouse_8', 'end': 'hospital_9', 'distance': 218},
#  {'start': 'warehouse_5', 'end': 'hospital_6', 'distance': 315},
#  {'start': 'warehouse_8', 'end': 'hospital_10', 'distance': 139},
#  {'start': 'warehouse_8', 'end': 'hospital_5', 'distance': 204},
#  {'start': 'warehouse_4', 'end': 'hospital_4', 'distance': 301},
#  {'start': 'plant_5', 'end': 'warehouse_8', 'distance': 162},
#  {'start': 'warehouse_3', 'end': 'hospital_4', 'distance': 48},
#  {'start': 'warehouse_2', 'end': 'hospital_6', 'distance': 363},
#  {'start': 'plant_5', 'end': 'warehouse_6', 'distance': 382},
#  {'start': 'warehouse_7', 'end': 'hospital_2', 'distance': 157},
#  {'start': 'warehouse_1', 'end': 'hospital_5', 'distance': 52},
#  {'start': 'warehouse_6', 'end': 'hospital_2', 'distance': 179},
#  {'start': 'plant_3', 'end': 'warehouse_3', 'distance': 239},
#  {'start': 'warehouse_2', 'end': 'hospital_8', 'distance': 12},
#  {'start': 'plant_4', 'end': 'warehouse_6', 'distance': 166},
#  {'start': 'warehouse_5', 'end': 'hospital_1', 'distance': 137},
#  {'start': 'plant_3', 'end': 'warehouse_5', 'distance': 299},
#  {'start': 'warehouse_3', 'end': 'hospital_1', 'distance': 111},
#  {'start': 'warehouse_1', 'end': 'hospital_4', 'distance': 57},
#  {'start': 'plant_2', 'end': 'warehouse_7', 'distance': 219},
#  {'start': 'plant_6', 'end': 'warehouse_3', 'distance': 298},
#  {'start': 'warehouse_6', 'end': 'hospital_3', 'distance': 115},
#  {'start': 'plant_2', 'end': 'warehouse_1', 'distance': 19},
#  {'start': 'plant_1', 'end': 'warehouse_3', 'distance': 162},
#  {'start': 'warehouse_2', 'end': 'hospital_9', 'distance': 161},
#  {'start': 'warehouse_5', 'end': 'hospital_4', 'distance': 104},
#  {'start': 'warehouse_7', 'end': 'hospital_10', 'distance': 129},
#  {'start': 'plant_3', 'end': 'warehouse_4', 'distance': 220},
#  {'start': 'plant_5', 'end': 'warehouse_5', 'distance': 153},
#  {'start': 'warehouse_2', 'end': 'hospital_10', 'distance': 168},
#  {'start': 'plant_6', 'end': 'warehouse_7', 'distance': 161},
#  {'start': 'warehouse_1', 'end': 'hospital_9', 'distance': 370},
#  {'start': 'warehouse_2', 'end': 'hospital_3', 'distance': 332},
#  {'start': 'warehouse_1', 'end': 'hospital_1', 'distance': 68},
#  {'start': 'plant_3', 'end': 'warehouse_7', 'distance': 124},
#  {'start': 'plant_2', 'end': 'warehouse_4', 'distance': 315},
#  {'start': 'warehouse_8', 'end': 'hospital_8', 'distance': 45},
#  {'start': 'plant_6', 'end': 'warehouse_8', 'distance': 225},
#  {'start': 'warehouse_3', 'end': 'hospital_10', 'distance': 212}]

# %% [markdown]
# **7. Create a PuLP LpProblem object and store it in the variable `model`.**

# %%
model = pulp.LpProblem("Vax_Watehouse_HW3",pulp.LpMinimize)

# %% [markdown]
# **8. Create and store your PuLP decision variables. Print out your Python structures that hold them.**

# %%
#names -------------
lp_variables_p_w = {}

for plant in plants:
    for warehouse in warehouses:
        # Create a dictionary entry referencing the decision variable for this plant-hospital pair
        lp_variables_p_w[(plant['name'], warehouse['name'])] = pulp.LpVariable(f"{plant['name']}_{warehouse['name']}", cat='Continuous', lowBound=0)

lp_variables_w_h = {}

for warehouse in warehouses:
    for hospital in hospitals:
        # Create a dictionary entry referencing the decision variable for this plant-hospital pair
        lp_variables_w_h[(warehouse['name'], hospital['name'])] = pulp.LpVariable(f"{warehouse['name']}_{hospital['name']}", cat='Continuous', lowBound=0)

#distances -------------
plant_to_wh_dist = {}

wh_to_hosp_dist = {}

for distance in distances:
    start_location = distance['start']
    end_location = distance['end']
    distance_v = distance['distance']

    # Check against actual plant and warehouse names via looping
    for plant in plants:
        for warehouse in warehouses:
            if start_location == plant['name'] and end_location == warehouse['name']:
                plant_to_wh_dist[(plant['name'], warehouse['name'])] = distance_v

    for warehouse in warehouses:
        for hospital in hospitals:
            if start_location == warehouse['name'] and end_location == hospital['name']:
                wh_to_hosp_dist[(warehouse['name'], hospital['name'])] = distance_v

open_warehouse = {}
for warehouse in warehouses:
    open_warehouse[warehouse['name']] = pulp.LpVariable(f"open_{warehouse['name']}", cat='Binary')

obj_plant_to_wh = 0

for plant, warehouse in lp_variables_p_w:
  obj_plant_to_wh += lp_variables_p_w[(plant, warehouse)] * plant_to_wh_dist[(plant, warehouse)]

obj_wh_to_hosp = 0

for warehouse, hospital in lp_variables_w_h:
    obj_wh_to_hosp += lp_variables_w_h[(warehouse, hospital)] * wh_to_hosp_dist[(warehouse, hospital)]

obj_proc_cost = 0

for warehouse in warehouses:
    for hospital in hospitals:
        dict_key = (warehouse['name'], hospital['name'])
        if dict_key in lp_variables_w_h:
            obj_proc_cost += lp_variables_w_h[dict_key] * warehouse['processing_cost']

obj_fix_cost = 0

for warehouse in warehouses:
    obj_fix_cost += open_warehouse[warehouse['name']] * warehouse['fixed_cost']

objective = obj_plant_to_wh + obj_wh_to_hosp + obj_proc_cost + obj_fix_cost

# %%
objective
# Out:
# 1000*open_warehouse_1 + 750*open_warehouse_2 + 290*open_warehouse_3 + 310*open_warehouse_4 + 1200*open_warehouse_5 + 1590*open_warehouse_6 + 410*open_warehouse_7 + 550*open_warehouse_8 + 203*plant_1_warehouse_1 + 270*plant_1_warehouse_2 + 162*plant_1_warehouse_3 + 129*plant_1_warehouse_4 + 222*plant_1_warehouse_5 + 177*plant_1_warehouse_6 + 17*plant_1_warehouse_7 + 213*plant_1_warehouse_8 + 19*plant_2_warehouse_1 + 214*plant_2_warehouse_2 + 106*plant_2_warehouse_3 + 315*plant_2_warehouse_4 + 166*plant_2_warehouse_5 + 63*plant_2_warehouse_6 + 219*plant_2_warehouse_7 + 157*plant_2_warehouse_8 + 138*plant_3_warehouse_1 + 347*plant_3_warehouse_2 + 239*plant_3_warehouse_3 + 220*plant_3_warehouse_4 + 299*plant_3_warehouse_5 + 70*plant_3_warehouse_6 + 124*plant_3_warehouse_7 + 290*plant_3_warehouse_8 + 98*plant_4_warehouse_1 + 111*plant_4_warehouse_2 + 13*plant_4_warehouse_3 + 240*plant_4_warehouse_4 + 63*plant_4_warehouse_5 + 166*plant_4_warehouse_6 + 144*plant_4_warehouse_7 + 60*plant_4_warehouse_8 + 314*plant_5_warehouse_1 + 105*plant_5_warehouse_2 + 213*plant_5_warehouse_3 + 246*plant_5_warehouse_4 + 153*plant_5_warehouse_5 + 382*plant_5_warehouse_6 + 358*plant_5_warehouse_7 + 162*plant_5_warehouse_8 + 341*plant_6_warehouse_1 + 254*plant_6_warehouse_2 + 298*plant_6_warehouse_3 + 49*plant_6_warehouse_4 + 272*plant_6_warehouse_5 + 315*plant_6_warehouse_6 + 161*plant_6_warehouse_7 + 225*plant_6_warehouse_8 + 88*warehouse_1_hospital_1 + 275*warehouse_1_hospital_10 + 131*warehouse_1_hospital_2 + 161*warehouse_1_hospital_3 + 77*warehouse_1_hospital_4 + 72*warehouse_1_hospital_5 + 210*warehouse_1_hospital_6 + 147*warehouse_1_hospital_7 + 217*warehouse_1_hospital_8 + 390*warehouse_1_hospital_9 + 188*warehouse_2_hospital_1 + 193*warehouse_2_hospital_10 + 123*warehouse_2_hospital_2 + 357*warehouse_2_hospital_3 + 177*warehouse_2_hospital_4 + 286*warehouse_2_hospital_5 + 388*warehouse_2_hospital_6 + 339*warehouse_2_hospital_7 + 37*warehouse_2_hospital_8 + 186*warehouse_2_hospital_9 + 141*warehouse_3_hospital_1 + 242*warehouse_3_hospital_10 + 40*warehouse_3_hospital_2 + 254*warehouse_3_hospital_3 + 78*warehouse_3_hospital_4 + 183*warehouse_3_hospital_5 + 285*warehouse_3_hospital_6 + 236*warehouse_3_hospital_7 + 126*warehouse_3_hospital_8 + 299*warehouse_3_hospital_9 + 394*warehouse_4_hospital_1 + 71*warehouse_4_hospital_10 + 283*warehouse_4_hospital_2 + 221*warehouse_4_hospital_3 + 331*warehouse_4_hospital_4 + 354*warehouse_4_hospital_5 + 252*warehouse_4_hospital_6 + 203*warehouse_4_hospital_7 + 229*warehouse_4_hospital_8 + 332*warehouse_4_hospital_9 + 162*warehouse_5_hospital_1 + 211*warehouse_5_hospital_10 + 75*warehouse_5_hospital_2 + 309*warehouse_5_hospital_3 + 129*warehouse_5_hospital_4 + 238*warehouse_5_hospital_5 + 340*warehouse_5_hospital_6 + 291*warehouse_5_hospital_7 + 61*warehouse_5_hospital_8 + 234*warehouse_5_hospital_9 + 124*warehouse_6_hospital_1 + 239*warehouse_6_hospital_10 + 189*warehouse_6_hospital_2 + 125*warehouse_6_hospital_3 + 135*warehouse_6_hospital_4 + 64*warehouse_6_hospital_5 + 174*warehouse_6_hospital_6 + 111*warehouse_6_hospital_7 + 275*warehouse_6_hospital_8 + 448*warehouse_6_hospital_9 + 293*warehouse_7_hospital_1 + 154*warehouse_7_hospital_10 + 182*warehouse_7_hospital_2 + 104*warehouse_7_hospital_3 + 230*warehouse_7_hospital_4 + 253*warehouse_7_hospital_5 + 135*warehouse_7_hospital_6 + 98*warehouse_7_hospital_7 + 266*warehouse_7_hospital_8 + 439*warehouse_7_hospital_9 + 194*warehouse_8_hospital_1 + 149*warehouse_8_hospital_10 + 83*warehouse_8_hospital_2 + 285*warehouse_8_hospital_3 + 131*warehouse_8_hospital_4 + 214*warehouse_8_hospital_5 + 316*warehouse_8_hospital_6 + 267*warehouse_8_hospital_7 + 55*warehouse_8_hospital_8 + 228*warehouse_8_hospital_9 + 0

# %% [markdown]
# **9. Add your objective function to your `model`.  Print your model to verify**

# %%
model += objective, 'Minimize transportation cost'

print(model)
# Out:
# Vax_Watehouse_HW3:
# MINIMIZE
# 1000*open_warehouse_1 + 750*open_warehouse_2 + 290*open_warehouse_3 + 310*open_warehouse_4 + 1200*open_warehouse_5 + 1590*open_warehouse_6 + 410*open_warehouse_7 + 550*open_warehouse_8 + 203*plant_1_warehouse_1 + 270*plant_1_warehouse_2 + 162*plant_1_warehouse_3 + 129*plant_1_warehouse_4 + 222*plant_1_warehouse_5 + 177*plant_1_warehouse_6 + 17*plant_1_warehouse_7 + 213*plant_1_warehouse_8 + 19*plant_2_warehouse_1 + 214*plant_2_warehouse_2 + 106*plant_2_warehouse_3 + 315*plant_2_warehouse_4 + 166*plant_2_warehouse_5 + 63*plant_2_warehouse_6 + 219*plant_2_warehouse_7 + 157*plant_2_warehouse_8 + 138*plant_3_warehouse_1 + 347*plant_3_warehouse_2 + 239*plant_3_warehouse_3 + 220*plant_3_warehouse_4 + 299*plant_3_warehouse_5 + 70*plant_3_warehouse_6 + 124*plant_3_warehouse_7 + 290*plant_3_warehouse_8 + 98*plant_4_warehouse_1 + 111*plant_4_warehouse_2 + 13*plant_4_warehouse_3 + 240*plant_4_warehouse_4 + 63*plant_4_warehouse_5 + 166*plant_4_warehouse_6 + 144*plant_4_warehouse_7 + 60*plant_4_warehouse_8 + 314*plant_5_warehouse_1 + 105*plant_5_warehouse_2 + 213*plant_5_warehouse_3 + 246*plant_5_warehouse_4 + 153*plant_5_warehouse_5 + 382*plant_5_warehouse_6 + 358*plant_5_warehouse_7 + 162*plant_5_warehouse_8 + 341*plant_6_warehouse_1 + 254*plant_6_warehouse_2 + 298*plant_6_warehouse_3 + 49*plant_6_warehouse_4 + 272*plant_6_warehouse_5 + 315*plant_6_warehouse_6 + 161*plant_6_warehouse_7 + 225*plant_6_warehouse_8 + 88*warehouse_1_hospital_1 + 275*warehouse_1_hospital_10 + 131*warehouse_1_hospital_2 + 161*warehouse_1_hospital_3 + 77*warehouse_1_hospital_4 + 72*warehouse_1_hospital_5 + 210*warehouse_1_hospital_6 + 147*warehouse_1_hospital_7 + 217*warehouse_1_hospital_8 + 390*warehouse_1_hospital_9 + 188*warehouse_2_hospital_1 + 193*warehouse_2_hospital_10 + 123*warehouse_2_hospital_2 + 357*warehouse_2_hospital_3 + 177*warehouse_2_hospital_4 + 286*warehouse_2_hospital_5 + 388*warehouse_2_hospital_6 + 339*warehouse_2_hospital_7 + 37*warehouse_2_hospital_8 + 186*warehouse_2_hospital_9 + 141*warehouse_3_hospital_1 + 242*warehouse_3_hospital_10 + 40*warehouse_3_hospital_2 + 254*warehouse_3_hospital_3 + 78*warehouse_3_hospital_4 + 183*warehouse_3_hospital_5 + 285*warehouse_3_hospital_6 + 236*warehouse_3_hospital_7 + 126*warehouse_3_hospital_8 + 299*warehouse_3_hospital_9 + 394*warehouse_4_hospital_1 + 71*warehouse_4_hospital_10 + 283*warehouse_4_hospital_2 + 221*warehouse_4_hospital_3 + 331*warehouse_4_hospital_4 + 354*warehouse_4_hospital_5 + 252*warehouse_4_hospital_6 + 203*warehouse_4_hospital_7 + 229*warehouse_4_hospital_8 + 332*warehouse_4_hospital_9 + 162*warehouse_5_hospital_1 + 211*warehouse_5_hospital_10 + 75*warehouse_5_hospital_2 + 309*warehouse_5_hospital_3 + 129*warehouse_5_hospital_4 + 238*warehouse_5_hospital_5 + 340*warehouse_5_hospital_6 + 291*warehouse_5_hospital_7 + 61*warehouse_5_hospital_8 + 234*warehouse_5_hospital_9 + 124*warehouse_6_hospital_1 + 239*warehouse_6_hospital_10 + 189*warehouse_6_hospital_2 + 125*warehouse_6_hospital_3 + 135*warehouse_6_hospital_4 + 64*warehouse_6_hospital_5 + 174*warehouse_6_hospital_6 + 111*warehouse_6_hospital_7 + 275*warehouse_6_hospital_8 + 448*warehouse_6_hospital_9 + 293*warehouse_7_hospital_1 + 154*warehouse_7_hospital_10 + 182*warehouse_7_hospital_2 + 104*warehouse_7_hospital_3 + 230*warehouse_7_hospital_4 + 253*warehouse_7_hospital_5 + 135*warehouse_7_hospital_6 + 98*warehouse_7_hospital_7 + 266*warehouse_7_hospital_8 + 439*warehouse_7_hospital_9 + 194*warehouse_8_hospital_1 + 149*warehouse_8_hospital_10 + 83*warehouse_8_hospital_2 + 285*warehouse_8_hospital_3 + 131*warehouse_8_hospital_4 + 214*warehouse_8_hospital_5 + 316*warehouse_8_hospital_6 + 267*warehouse_8_hospital_7 + 55*warehouse_8_hospital_8 + 228*warehouse_8_hospital_9 + 0
# VARIABLES
# 0 <= open_warehouse_1 <= 1 Integer
# 0 <= open_warehouse_2 <= 1 Integer
# 0 <= open_warehouse_3 <= 1 Integer
# 0 <= open_warehouse_4 <= 1 Integer
# 0 <= open_warehouse_5 <= 1 Integer
# 0 <= open_warehouse_6 <= 1 Integer
# 0 <= open_warehouse_7 <= 1 Integer
# 0 <= open_warehouse_8 <= 1 Integer
# plant_1_warehouse_1 Continuous
# plant_1_warehouse_2 Continuous
# plant_1_warehouse_3 Continuous
# plant_1_warehouse_4 Continuous
# plant_1_warehouse_5 Continuous
# plant_1_warehouse_6 Continuous
# plant_1_warehouse_7 Continuous
# plant_1_warehouse_8 Continuous
# plant_2_warehouse_1 Continuous
# plant_2_warehouse_2 Continuous
# plant_2_warehouse_3 Continuous
# plant_2_warehouse_4 Continuous
# plant_2_warehouse_5 Continuous
# plant_2_warehouse_6 Continuous
# plant_2_warehouse_7 Continuous
# plant_2_warehouse_8 Continuous
# plant_3_warehouse_1 Continuous
# plant_3_warehouse_2 Continuous
# plant_3_warehouse_3 Continuous
# plant_3_warehouse_4 Continuous
# plant_3_warehouse_5 Continuous
# plant_3_warehouse_6 Continuous
# plant_3_warehouse_7 Continuous
# plant_3_warehouse_8 Continuous
# plant_4_warehouse_1 Continuous
# plant_4_warehouse_2 Continuous
# plant_4_warehouse_3 Continuous
# plant_4_warehouse_4 Continuous
# plant_4_warehouse_5 Continuous
# plant_4_warehouse_6 Continuous
# plant_4_warehouse_7 Continuous
# plant_4_warehouse_8 Continuous
# plant_5_warehouse_1 Continuous
# plant_5_warehouse_2 Continuous
# plant_5_warehouse_3 Continuous
# plant_5_warehouse_4 Continuous
# plant_5_warehouse_5 Continuous
# plant_5_warehouse_6 Continuous
# plant_5_warehouse_7 Continuous
# plant_5_warehouse_8 Continuous
# plant_6_warehouse_1 Continuous
# plant_6_warehouse_2 Continuous
# plant_6_warehouse_3 Continuous
# plant_6_warehouse_4 Continuous
# plant_6_warehouse_5 Continuous
# plant_6_warehouse_6 Continuous
# plant_6_warehouse_7 Continuous
# plant_6_warehouse_8 Continuous
# warehouse_1_hospital_1 Continuous
# warehouse_1_hospital_10 Continuous
# warehouse_1_hospital_2 Continuous
# warehouse_1_hospital_3 Continuous
# warehouse_1_hospital_4 Continuous
# warehouse_1_hospital_5 Continuous
# warehouse_1_hospital_6 Continuous
# warehouse_1_hospital_7 Continuous
# warehouse_1_hospital_8 Continuous
# warehouse_1_hospital_9 Continuous
# warehouse_2_hospital_1 Continuous
# warehouse_2_hospital_10 Continuous
# warehouse_2_hospital_2 Continuous
# warehouse_2_hospital_3 Continuous
# warehouse_2_hospital_4 Continuous
# warehouse_2_hospital_5 Continuous
# warehouse_2_hospital_6 Continuous
# warehouse_2_hospital_7 Continuous
# warehouse_2_hospital_8 Continuous
# warehouse_2_hospital_9 Continuous
# warehouse_3_hospital_1 Continuous
# warehouse_3_hospital_10 Continuous
# warehouse_3_hospital_2 Continuous
# warehouse_3_hospital_3 Continuous
# warehouse_3_hospital_4 Continuous
# warehouse_3_hospital_5 Continuous
# warehouse_3_hospital_6 Continuous
# warehouse_3_hospital_7 Continuous
# warehouse_3_hospital_8 Continuous
# warehouse_3_hospital_9 Continuous
# warehouse_4_hospital_1 Continuous
# warehouse_4_hospital_10 Continuous
# warehouse_4_hospital_2 Continuous
# warehouse_4_hospital_3 Continuous
# warehouse_4_hospital_4 Continuous
# warehouse_4_hospital_5 Continuous
# warehouse_4_hospital_6 Continuous
# warehouse_4_hospital_7 Continuous
# warehouse_4_hospital_8 Continuous
# warehouse_4_hospital_9 Continuous
# warehouse_5_hospital_1 Continuous
# warehouse_5_hospital_10 Continuous
# warehouse_5_hospital_2 Continuous
# warehouse_5_hospital_3 Continuous
# warehouse_5_hospital_4 Continuous
# warehouse_5_hospital_5 Continuous
# warehouse_5_hospital_6 Continuous
# warehouse_5_hospital_7 Continuous
# warehouse_5_hospital_8 Continuous
# warehouse_5_hospital_9 Continuous
# warehouse_6_hospital_1 Continuous
# warehouse_6_hospital_10 Continuous
# warehouse_6_hospital_2 Continuous
# warehouse_6_hospital_3 Continuous
# warehouse_6_hospital_4 Continuous
# warehouse_6_hospital_5 Continuous
# warehouse_6_hospital_6 Continuous
# warehouse_6_hospital_7 Continuous
# warehouse_6_hospital_8 Continuous
# warehouse_6_hospital_9 Continuous
# warehouse_7_hospital_1 Continuous
# warehouse_7_hospital_10 Continuous
# warehouse_7_hospital_2 Continuous
# warehouse_7_hospital_3 Continuous
# warehouse_7_hospital_4 Continuous
# warehouse_7_hospital_5 Continuous
# warehouse_7_hospital_6 Continuous
# warehouse_7_hospital_7 Continuous
# warehouse_7_hospital_8 Continuous
# warehouse_7_hospital_9 Continuous
# warehouse_8_hospital_1 Continuous
# warehouse_8_hospital_10 Continuous
# warehouse_8_hospital_2 Continuous
# warehouse_8_hospital_3 Continuous
# warehouse_8_hospital_4 Continuous
# warehouse_8_hospital_5 Continuous
# warehouse_8_hospital_6 Continuous
# warehouse_8_hospital_7 Continuous
# warehouse_8_hospital_8 Continuous
# warehouse_8_hospital_9 Continuous

# %% [markdown]
# **10. Add all of your constraints to your `model`.   Use python comments to document each type of constraint before you add them.**

# %%
# Plant capacity
for plant in plants:
    for warehouse in warehouses:
        if (plant['name'], warehouse['name']) in lp_variables_p_w:
            model += (
                lp_variables_p_w[(plant['name'], warehouse['name'])] <= plant['capacity'],
                f"plant_capacity_{plant['name']}_to_{warehouse['name']}"
            )

# Warehouse capacity
for warehouse in warehouses:
    for hospital in hospitals:
        if (warehouse['name'], hospital['name']) in lp_variables_w_h:
            model += (
                lp_variables_w_h[(warehouse['name'], hospital['name'])] <= warehouse['capacity'] * open_warehouse[warehouse['name']],
                f"warehouse_capacity_{warehouse['name']}_to_{hospital['name']}"
            )

# Warehouse vaccine in and out


for warehouse in warehouses:
    vac_in = 0
    vac_out = 0
    for plant in plants:
        if (plant['name'], warehouse['name']) in lp_variables_p_w:
            vac_in += lp_variables_p_w[(plant['name'], warehouse['name'])]
    for hospital in hospitals:
        if (warehouse['name'], hospital['name']) in lp_variables_w_h:
            vac_out += lp_variables_w_h[(warehouse['name'], hospital['name'])]
    model += (vac_in == vac_out, f"balance_{warehouse['name']}")

# Total flow of vaccines should be equal to the total available vaccines
total_vaccines = 0

for plant in plants:
    total_vaccines += plant['capacity']

total_distributed_vaccines = 0
for warehouse in warehouses:
    for hospital in hospitals:
        if (warehouse['name'], hospital['name']) in lp_variables_w_h:
            total_distributed_vaccines += lp_variables_w_h[(warehouse['name'], hospital['name'])]

model += (total_distributed_vaccines == total_vaccines, "total_vaccines")

# Ensure that no hospital receives more vaccines than its demand
for hospital in hospitals:
    total_flow_to_hospital = 0
    for warehouse in warehouses:
        if (warehouse['name'], hospital['name']) in lp_variables_w_h:
            total_flow_to_hospital += lp_variables_w_h[(warehouse['name'], hospital['name'])]
    model += (
        total_flow_to_hospital <= hospital['demand'],
        f"hospital_demand_{hospital['name']}"
    )

# Only allow flow through warehouse if it's open


for warehouse in warehouses:
    for hospital in hospitals:
        if (warehouse['name'], hospital['name']) in lp_variables_w_h:
            model += (
                lp_variables_w_h[(warehouse['name'], hospital['name'])] <= warehouse['capacity'] * open_warehouse[warehouse['name']],
                f"warehouse_open_{warehouse['name']}_to_{hospital['name']}"
            )

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# **11. Display your model with `print(model)`, check that all is OK**

# %%
print(model)
# Out:
# Vax_Watehouse_HW3:
# MINIMIZE
# 1000*open_warehouse_1 + 750*open_warehouse_2 + 290*open_warehouse_3 + 310*open_warehouse_4 + 1200*open_warehouse_5 + 1590*open_warehouse_6 + 410*open_warehouse_7 + 550*open_warehouse_8 + 203*plant_1_warehouse_1 + 270*plant_1_warehouse_2 + 162*plant_1_warehouse_3 + 129*plant_1_warehouse_4 + 222*plant_1_warehouse_5 + 177*plant_1_warehouse_6 + 17*plant_1_warehouse_7 + 213*plant_1_warehouse_8 + 19*plant_2_warehouse_1 + 214*plant_2_warehouse_2 + 106*plant_2_warehouse_3 + 315*plant_2_warehouse_4 + 166*plant_2_warehouse_5 + 63*plant_2_warehouse_6 + 219*plant_2_warehouse_7 + 157*plant_2_warehouse_8 + 138*plant_3_warehouse_1 + 347*plant_3_warehouse_2 + 239*plant_3_warehouse_3 + 220*plant_3_warehouse_4 + 299*plant_3_warehouse_5 + 70*plant_3_warehouse_6 + 124*plant_3_warehouse_7 + 290*plant_3_warehouse_8 + 98*plant_4_warehouse_1 + 111*plant_4_warehouse_2 + 13*plant_4_warehouse_3 + 240*plant_4_warehouse_4 + 63*plant_4_warehouse_5 + 166*plant_4_warehouse_6 + 144*plant_4_warehouse_7 + 60*plant_4_warehouse_8 + 314*plant_5_warehouse_1 + 105*plant_5_warehouse_2 + 213*plant_5_warehouse_3 + 246*plant_5_warehouse_4 + 153*plant_5_warehouse_5 + 382*plant_5_warehouse_6 + 358*plant_5_warehouse_7 + 162*plant_5_warehouse_8 + 341*plant_6_warehouse_1 + 254*plant_6_warehouse_2 + 298*plant_6_warehouse_3 + 49*plant_6_warehouse_4 + 272*plant_6_warehouse_5 + 315*plant_6_warehouse_6 + 161*plant_6_warehouse_7 + 225*plant_6_warehouse_8 + 88*warehouse_1_hospital_1 + 275*warehouse_1_hospital_10 + 131*warehouse_1_hospital_2 + 161*warehouse_1_hospital_3 + 77*warehouse_1_hospital_4 + 72*warehouse_1_hospital_5 + 210*warehouse_1_hospital_6 + 147*warehouse_1_hospital_7 + 217*warehouse_1_hospital_8 + 390*warehouse_1_hospital_9 + 188*warehouse_2_hospital_1 + 193*warehouse_2_hospital_10 + 123*warehouse_2_hospital_2 + 357*warehouse_2_hospital_3 + 177*warehouse_2_hospital_4 + 286*warehouse_2_hospital_5 + 388*warehouse_2_hospital_6 + 339*warehouse_2_hospital_7 + 37*warehouse_2_hospital_8 + 186*warehouse_2_hospital_9 + 141*warehouse_3_hospital_1 + 242*warehouse_3_hospital_10 + 40*warehouse_3_hospital_2 + 254*warehouse_3_hospital_3 + 78*warehouse_3_hospital_4 + 183*warehouse_3_hospital_5 + 285*warehouse_3_hospital_6 + 236*warehouse_3_hospital_7 + 126*warehouse_3_hospital_8 + 299*warehouse_3_hospital_9 + 394*warehouse_4_hospital_1 + 71*warehouse_4_hospital_10 + 283*warehouse_4_hospital_2 + 221*warehouse_4_hospital_3 + 331*warehouse_4_hospital_4 + 354*warehouse_4_hospital_5 + 252*warehouse_4_hospital_6 + 203*warehouse_4_hospital_7 + 229*warehouse_4_hospital_8 + 332*warehouse_4_hospital_9 + 162*warehouse_5_hospital_1 + 211*warehouse_5_hospital_10 + 75*warehouse_5_hospital_2 + 309*warehouse_5_hospital_3 + 129*warehouse_5_hospital_4 + 238*warehouse_5_hospital_5 + 340*warehouse_5_hospital_6 + 291*warehouse_5_hospital_7 + 61*warehouse_5_hospital_8 + 234*warehouse_5_hospital_9 + 124*warehouse_6_hospital_1 + 239*warehouse_6_hospital_10 + 189*warehouse_6_hospital_2 + 125*warehouse_6_hospital_3 + 135*warehouse_6_hospital_4 + 64*warehouse_6_hospital_5 + 174*warehouse_6_hospital_6 + 111*warehouse_6_hospital_7 + 275*warehouse_6_hospital_8 + 448*warehouse_6_hospital_9 + 293*warehouse_7_hospital_1 + 154*warehouse_7_hospital_10 + 182*warehouse_7_hospital_2 + 104*warehouse_7_hospital_3 + 230*warehouse_7_hospital_4 + 253*warehouse_7_hospital_5 + 135*warehouse_7_hospital_6 + 98*warehouse_7_hospital_7 + 266*warehouse_7_hospital_8 + 439*warehouse_7_hospital_9 + 194*warehouse_8_hospital_1 + 149*warehouse_8_hospital_10 + 83*warehouse_8_hospital_2 + 285*warehouse_8_hospital_3 + 131*warehouse_8_hospital_4 + 214*warehouse_8_hospital_5 + 316*warehouse_8_hospital_6 + 267*warehouse_8_hospital_7 + 55*warehouse_8_hospital_8 + 228*warehouse_8_hospital_9 + 0
# SUBJECT TO
# plant_capacity_plant_6_to_warehouse_8: plant_6_warehouse_8 <= 100
#
# plant_capacity_plant_6_to_warehouse_5: plant_6_warehouse_5 <= 100
#
# plant_capacity_plant_6_to_warehouse_4: plant_6_warehouse_4 <= 100
#
# plant_capacity_plant_6_to_warehouse_6: plant_6_warehouse_6 <= 100
#
# plant_capacity_plant_6_to_warehouse_3: plant_6_warehouse_3 <= 100
#
# plant_capacity_plant_6_to_warehouse_7: plant_6_warehouse_7 <= 100
#
# plant_capacity_plant_6_to_warehouse_2: plant_6_warehouse_2 <= 100
#
# plant_capacity_plant_6_to_warehouse_1: plant_6_warehouse_1 <= 100
#
# plant_capacity_plant_5_to_warehouse_8: plant_5_warehouse_8 <= 100
#
# plant_capacity_plant_5_to_warehouse_5: plant_5_warehouse_5 <= 100
#
# plant_capacity_plant_5_to_warehouse_4: plant_5_warehouse_4 <= 100
#
# plant_capacity_plant_5_to_warehouse_6: plant_5_warehouse_6 <= 100
#
# plant_capacity_plant_5_to_warehouse_3: plant_5_warehouse_3 <= 100
#
# plant_capacity_plant_5_to_warehouse_7: plant_5_warehouse_7 <= 100
#
# plant_capacity_plant_5_to_warehouse_2: plant_5_warehouse_2 <= 100
#
# plant_capacity_plant_5_to_warehouse_1: plant_5_warehouse_1 <= 100
#
# plant_capacity_plant_2_to_warehouse_8: plant_2_warehouse_8 <= 60
#
# plant_capacity_plant_2_to_warehouse_5: plant_2_warehouse_5 <= 60
#
# plant_capacity_plant_2_to_warehouse_4: plant_2_warehouse_4 <= 60
#
# plant_capacity_plant_2_to_warehouse_6: plant_2_warehouse_6 <= 60
#
# plant_capacity_plant_2_to_warehouse_3: plant_2_warehouse_3 <= 60
#
# plant_capacity_plant_2_to_warehouse_7: plant_2_warehouse_7 <= 60
#
# plant_capacity_plant_2_to_warehouse_2: plant_2_warehouse_2 <= 60
#
# plant_capacity_plant_2_to_warehouse_1: plant_2_warehouse_1 <= 60
#
# plant_capacity_plant_3_to_warehouse_8: plant_3_warehouse_8 <= 150
#
# plant_capacity_plant_3_to_warehouse_5: plant_3_warehouse_5 <= 150
#
# plant_capacity_plant_3_to_warehouse_4: plant_3_warehouse_4 <= 150
#
# plant_capacity_plant_3_to_warehouse_6: plant_3_warehouse_6 <= 150
#
# plant_capacity_plant_3_to_warehouse_3: plant_3_warehouse_3 <= 150
#
# plant_capacity_plant_3_to_warehouse_7: plant_3_warehouse_7 <= 150
#
# plant_capacity_plant_3_to_warehouse_2: plant_3_warehouse_2 <= 150
#
# plant_capacity_plant_3_to_warehouse_1: plant_3_warehouse_1 <= 150
#
# plant_capacity_plant_1_to_warehouse_8: plant_1_warehouse_8 <= 200
#
# plant_capacity_plant_1_to_warehouse_5: plant_1_warehouse_5 <= 200
#
# plant_capacity_plant_1_to_warehouse_4: plant_1_warehouse_4 <= 200
#
# plant_capacity_plant_1_to_warehouse_6: plant_1_warehouse_6 <= 200
#
# plant_capacity_plant_1_to_warehouse_3: plant_1_warehouse_3 <= 200
#
# plant_capacity_plant_1_to_warehouse_7: plant_1_warehouse_7 <= 200
#
# plant_capacity_plant_1_to_warehouse_2: plant_1_warehouse_2 <= 200
#
# plant_capacity_plant_1_to_warehouse_1: plant_1_warehouse_1 <= 200
#
# plant_capacity_plant_4_to_warehouse_8: plant_4_warehouse_8 <= 40
#
# plant_capacity_plant_4_to_warehouse_5: plant_4_warehouse_5 <= 40
#
# plant_capacity_plant_4_to_warehouse_4: plant_4_warehouse_4 <= 40
#
# plant_capacity_plant_4_to_warehouse_6: plant_4_warehouse_6 <= 40
#
# plant_capacity_plant_4_to_warehouse_3: plant_4_warehouse_3 <= 40
#
# plant_capacity_plant_4_to_warehouse_7: plant_4_warehouse_7 <= 40
#
# plant_capacity_plant_4_to_warehouse_2: plant_4_warehouse_2 <= 40
#
# plant_capacity_plant_4_to_warehouse_1: plant_4_warehouse_1 <= 40
#
# warehouse_capacity_warehouse_8_to_hospital_2: - 100 open_warehouse_8
#  + warehouse_8_hospital_2 <= 0
#
# warehouse_capacity_warehouse_8_to_hospital_10: - 100 open_warehouse_8
#  + warehouse_8_hospital_10 <= 0
#
# warehouse_capacity_warehouse_8_to_hospital_6: - 100 open_warehouse_8
#  + warehouse_8_hospital_6 <= 0
#
# warehouse_capacity_warehouse_8_to_hospital_1: - 100 open_warehouse_8
#  + warehouse_8_hospital_1 <= 0
#
# warehouse_capacity_warehouse_8_to_hospital_4: - 100 open_warehouse_8
#  + warehouse_8_hospital_4 <= 0
#
# warehouse_capacity_warehouse_8_to_hospital_7: - 100 open_warehouse_8
#  + warehouse_8_hospital_7 <= 0
#
# warehouse_capacity_warehouse_8_to_hospital_5: - 100 open_warehouse_8
#  + warehouse_8_hospital_5 <= 0
#
# warehouse_capacity_warehouse_8_to_hospital_8: - 100 open_warehouse_8
#  + warehouse_8_hospital_8 <= 0
#
# warehouse_capacity_warehouse_8_to_hospital_9: - 100 open_warehouse_8
#  + warehouse_8_hospital_9 <= 0
#
# warehouse_capacity_warehouse_8_to_hospital_3: - 100 open_warehouse_8
#  + warehouse_8_hospital_3 <= 0
#
# warehouse_capacity_warehouse_5_to_hospital_2: - 80 open_warehouse_5
#  + warehouse_5_hospital_2 <= 0
#
# warehouse_capacity_warehouse_5_to_hospital_10: - 80 open_warehouse_5
#  + warehouse_5_hospital_10 <= 0
#
# warehouse_capacity_warehouse_5_to_hospital_6: - 80 open_warehouse_5
#  + warehouse_5_hospital_6 <= 0
#
# warehouse_capacity_warehouse_5_to_hospital_1: - 80 open_warehouse_5
#  + warehouse_5_hospital_1 <= 0
#
# warehouse_capacity_warehouse_5_to_hospital_4: - 80 open_warehouse_5
#  + warehouse_5_hospital_4 <= 0
#
# warehouse_capacity_warehouse_5_to_hospital_7: - 80 open_warehouse_5
#  + warehouse_5_hospital_7 <= 0
#
# warehouse_capacity_warehouse_5_to_hospital_5: - 80 open_warehouse_5
#  + warehouse_5_hospital_5 <= 0
#
# warehouse_capacity_warehouse_5_to_hospital_8: - 80 open_warehouse_5
#  + warehouse_5_hospital_8 <= 0
#
# warehouse_capacity_warehouse_5_to_hospital_9: - 80 open_warehouse_5
#  + warehouse_5_hospital_9 <= 0
#
# warehouse_capacity_warehouse_5_to_hospital_3: - 80 open_warehouse_5
#  + warehouse_5_hospital_3 <= 0
#
# warehouse_capacity_warehouse_4_to_hospital_2: - 100 open_warehouse_4
#  + warehouse_4_hospital_2 <= 0
#
# warehouse_capacity_warehouse_4_to_hospital_10: - 100 open_warehouse_4
#  + warehouse_4_hospital_10 <= 0
#
# warehouse_capacity_warehouse_4_to_hospital_6: - 100 open_warehouse_4
#  + warehouse_4_hospital_6 <= 0
#
# warehouse_capacity_warehouse_4_to_hospital_1: - 100 open_warehouse_4
#  + warehouse_4_hospital_1 <= 0
#
# warehouse_capacity_warehouse_4_to_hospital_4: - 100 open_warehouse_4
#  + warehouse_4_hospital_4 <= 0
#
# warehouse_capacity_warehouse_4_to_hospital_7: - 100 open_warehouse_4
#  + warehouse_4_hospital_7 <= 0
#
# warehouse_capacity_warehouse_4_to_hospital_5: - 100 open_warehouse_4
#  + warehouse_4_hospital_5 <= 0
#
# warehouse_capacity_warehouse_4_to_hospital_8: - 100 open_warehouse_4
#  + warehouse_4_hospital_8 <= 0
#
# warehouse_capacity_warehouse_4_to_hospital_9: - 100 open_warehouse_4
#  + warehouse_4_hospital_9 <= 0
#
# warehouse_capacity_warehouse_4_to_hospital_3: - 100 open_warehouse_4
#  + warehouse_4_hospital_3 <= 0
#
# warehouse_capacity_warehouse_6_to_hospital_2: - 290 open_warehouse_6
#  + warehouse_6_hospital_2 <= 0
#
# warehouse_capacity_warehouse_6_to_hospital_10: - 290 open_warehouse_6
#  + warehouse_6_hospital_10 <= 0
#
# warehouse_capacity_warehouse_6_to_hospital_6: - 290 open_warehouse_6
#  + warehouse_6_hospital_6 <= 0
#
# warehouse_capacity_warehouse_6_to_hospital_1: - 290 open_warehouse_6
#  + warehouse_6_hospital_1 <= 0
#
# warehouse_capacity_warehouse_6_to_hospital_4: - 290 open_warehouse_6
#  + warehouse_6_hospital_4 <= 0
#
# warehouse_capacity_warehouse_6_to_hospital_7: - 290 open_warehouse_6
#  + warehouse_6_hospital_7 <= 0
#
# warehouse_capacity_warehouse_6_to_hospital_5: - 290 open_warehouse_6
#  + warehouse_6_hospital_5 <= 0
#
# warehouse_capacity_warehouse_6_to_hospital_8: - 290 open_warehouse_6
#  + warehouse_6_hospital_8 <= 0
#
# warehouse_capacity_warehouse_6_to_hospital_9: - 290 open_warehouse_6
#  + warehouse_6_hospital_9 <= 0
#
# warehouse_capacity_warehouse_6_to_hospital_3: - 290 open_warehouse_6
#  + warehouse_6_hospital_3 <= 0
#
# warehouse_capacity_warehouse_3_to_hospital_2: - 80 open_warehouse_3
#  + warehouse_3_hospital_2 <= 0
#
# warehouse_capacity_warehouse_3_to_hospital_10: - 80 open_warehouse_3
#  + warehouse_3_hospital_10 <= 0
#
# warehouse_capacity_warehouse_3_to_hospital_6: - 80 open_warehouse_3
#  + warehouse_3_hospital_6 <= 0
#
# warehouse_capacity_warehouse_3_to_hospital_1: - 80 open_warehouse_3
#  + warehouse_3_hospital_1 <= 0
#
# warehouse_capacity_warehouse_3_to_hospital_4: - 80 open_warehouse_3
#  + warehouse_3_hospital_4 <= 0
#
# warehouse_capacity_warehouse_3_to_hospital_7: - 80 open_warehouse_3
#  + warehouse_3_hospital_7 <= 0
#
# warehouse_capacity_warehouse_3_to_hospital_5: - 80 open_warehouse_3
#  + warehouse_3_hospital_5 <= 0
#
# warehouse_capacity_warehouse_3_to_hospital_8: - 80 open_warehouse_3
#  + warehouse_3_hospital_8 <= 0
#
# warehouse_capacity_warehouse_3_to_hospital_9: - 80 open_warehouse_3
#  + warehouse_3_hospital_9 <= 0
#
# warehouse_capacity_warehouse_3_to_hospital_3: - 80 open_warehouse_3
#  + warehouse_3_hospital_3 <= 0
#
# warehouse_capacity_warehouse_7_to_hospital_2: - 50 open_warehouse_7
#  + warehouse_7_hospital_2 <= 0
#
# warehouse_capacity_warehouse_7_to_hospital_10: - 50 open_warehouse_7
#  + warehouse_7_hospital_10 <= 0
#
# warehouse_capacity_warehouse_7_to_hospital_6: - 50 open_warehouse_7
#  + warehouse_7_hospital_6 <= 0
#
# warehouse_capacity_warehouse_7_to_hospital_1: - 50 open_warehouse_7
#  + warehouse_7_hospital_1 <= 0
#
# warehouse_capacity_warehouse_7_to_hospital_4: - 50 open_warehouse_7
#  + warehouse_7_hospital_4 <= 0
#
# warehouse_capacity_warehouse_7_to_hospital_7: - 50 open_warehouse_7
#  + warehouse_7_hospital_7 <= 0
#
# warehouse_capacity_warehouse_7_to_hospital_5: - 50 open_warehouse_7
#  + warehouse_7_hospital_5 <= 0
#
# warehouse_capacity_warehouse_7_to_hospital_8: - 50 open_warehouse_7
#  + warehouse_7_hospital_8 <= 0
#
# warehouse_capacity_warehouse_7_to_hospital_9: - 50 open_warehouse_7
#  + warehouse_7_hospital_9 <= 0
#
# warehouse_capacity_warehouse_7_to_hospital_3: - 50 open_warehouse_7
#  + warehouse_7_hospital_3 <= 0
#
# warehouse_capacity_warehouse_2_to_hospital_2: - 200 open_warehouse_2
#  + warehouse_2_hospital_2 <= 0
#
# warehouse_capacity_warehouse_2_to_hospital_10: - 200 open_warehouse_2
#  + warehouse_2_hospital_10 <= 0
#
# warehouse_capacity_warehouse_2_to_hospital_6: - 200 open_warehouse_2
#  + warehouse_2_hospital_6 <= 0
#
# warehouse_capacity_warehouse_2_to_hospital_1: - 200 open_warehouse_2
#  + warehouse_2_hospital_1 <= 0
#
# warehouse_capacity_warehouse_2_to_hospital_4: - 200 open_warehouse_2
#  + warehouse_2_hospital_4 <= 0
#
# warehouse_capacity_warehouse_2_to_hospital_7: - 200 open_warehouse_2
#  + warehouse_2_hospital_7 <= 0
#
# warehouse_capacity_warehouse_2_to_hospital_5: - 200 open_warehouse_2
#  + warehouse_2_hospital_5 <= 0
#
# warehouse_capacity_warehouse_2_to_hospital_8: - 200 open_warehouse_2
#  + warehouse_2_hospital_8 <= 0
#
# warehouse_capacity_warehouse_2_to_hospital_9: - 200 open_warehouse_2
#  + warehouse_2_hospital_9 <= 0
#
# warehouse_capacity_warehouse_2_to_hospital_3: - 200 open_warehouse_2
#  + warehouse_2_hospital_3 <= 0
#
# warehouse_capacity_warehouse_1_to_hospital_2: - 200 open_warehouse_1
#  + warehouse_1_hospital_2 <= 0
#
# warehouse_capacity_warehouse_1_to_hospital_10: - 200 open_warehouse_1
#  + warehouse_1_hospital_10 <= 0
#
# warehouse_capacity_warehouse_1_to_hospital_6: - 200 open_warehouse_1
#  + warehouse_1_hospital_6 <= 0
#
# warehouse_capacity_warehouse_1_to_hospital_1: - 200 open_warehouse_1
#  + warehouse_1_hospital_1 <= 0
#
# warehouse_capacity_warehouse_1_to_hospital_4: - 200 open_warehouse_1
#  + warehouse_1_hospital_4 <= 0
#
# warehouse_capacity_warehouse_1_to_hospital_7: - 200 open_warehouse_1
#  + warehouse_1_hospital_7 <= 0
#
# warehouse_capacity_warehouse_1_to_hospital_5: - 200 open_warehouse_1
#  + warehouse_1_hospital_5 <= 0
#
# warehouse_capacity_warehouse_1_to_hospital_8: - 200 open_warehouse_1
#  + warehouse_1_hospital_8 <= 0
#
# warehouse_capacity_warehouse_1_to_hospital_9: - 200 open_warehouse_1
#  + warehouse_1_hospital_9 <= 0
#
# warehouse_capacity_warehouse_1_to_hospital_3: - 200 open_warehouse_1
#  + warehouse_1_hospital_3 <= 0
#
# balance_warehouse_8: plant_1_warehouse_8 + plant_2_warehouse_8
#  + plant_3_warehouse_8 + plant_4_warehouse_8 + plant_5_warehouse_8
#  + plant_6_warehouse_8 - warehouse_8_hospital_1 - warehouse_8_hospital_10
#  - warehouse_8_hospital_2 - warehouse_8_hospital_3 - warehouse_8_hospital_4
#  - warehouse_8_hospital_5 - warehouse_8_hospital_6 - warehouse_8_hospital_7
#  - warehouse_8_hospital_8 - warehouse_8_hospital_9 = 0
#
# balance_warehouse_5: plant_1_warehouse_5 + plant_2_warehouse_5
#  + plant_3_warehouse_5 + plant_4_warehouse_5 + plant_5_warehouse_5
#  + plant_6_warehouse_5 - warehouse_5_hospital_1 - warehouse_5_hospital_10
#  - warehouse_5_hospital_2 - warehouse_5_hospital_3 - warehouse_5_hospital_4
#  - warehouse_5_hospital_5 - warehouse_5_hospital_6 - warehouse_5_hospital_7
#  - warehouse_5_hospital_8 - warehouse_5_hospital_9 = 0
#
# balance_warehouse_4: plant_1_warehouse_4 + plant_2_warehouse_4
#  + plant_3_warehouse_4 + plant_4_warehouse_4 + plant_5_warehouse_4
#  + plant_6_warehouse_4 - warehouse_4_hospital_1 - warehouse_4_hospital_10
#  - warehouse_4_hospital_2 - warehouse_4_hospital_3 - warehouse_4_hospital_4
#  - warehouse_4_hospital_5 - warehouse_4_hospital_6 - warehouse_4_hospital_7
#  - warehouse_4_hospital_8 - warehouse_4_hospital_9 = 0
#
# balance_warehouse_6: plant_1_warehouse_6 + plant_2_warehouse_6
#  + plant_3_warehouse_6 + plant_4_warehouse_6 + plant_5_warehouse_6
#  + plant_6_warehouse_6 - warehouse_6_hospital_1 - warehouse_6_hospital_10
#  - warehouse_6_hospital_2 - warehouse_6_hospital_3 - warehouse_6_hospital_4
#  - warehouse_6_hospital_5 - warehouse_6_hospital_6 - warehouse_6_hospital_7
#  - warehouse_6_hospital_8 - warehouse_6_hospital_9 = 0
#
# balance_warehouse_3: plant_1_warehouse_3 + plant_2_warehouse_3
#  + plant_3_warehouse_3 + plant_4_warehouse_3 + plant_5_warehouse_3
#  + plant_6_warehouse_3 - warehouse_3_hospital_1 - warehouse_3_hospital_10
#  - warehouse_3_hospital_2 - warehouse_3_hospital_3 - warehouse_3_hospital_4
#  - warehouse_3_hospital_5 - warehouse_3_hospital_6 - warehouse_3_hospital_7
#  - warehouse_3_hospital_8 - warehouse_3_hospital_9 = 0
#
# balance_warehouse_7: plant_1_warehouse_7 + plant_2_warehouse_7
#  + plant_3_warehouse_7 + plant_4_warehouse_7 + plant_5_warehouse_7
#  + plant_6_warehouse_7 - warehouse_7_hospital_1 - warehouse_7_hospital_10
#  - warehouse_7_hospital_2 - warehouse_7_hospital_3 - warehouse_7_hospital_4
#  - warehouse_7_hospital_5 - warehouse_7_hospital_6 - warehouse_7_hospital_7
#  - warehouse_7_hospital_8 - warehouse_7_hospital_9 = 0
#
# balance_warehouse_2: plant_1_warehouse_2 + plant_2_warehouse_2
#  + plant_3_warehouse_2 + plant_4_warehouse_2 + plant_5_warehouse_2
#  + plant_6_warehouse_2 - warehouse_2_hospital_1 - warehouse_2_hospital_10
#  - warehouse_2_hospital_2 - warehouse_2_hospital_3 - warehouse_2_hospital_4
#  - warehouse_2_hospital_5 - warehouse_2_hospital_6 - warehouse_2_hospital_7
#  - warehouse_2_hospital_8 - warehouse_2_hospital_9 = 0
#
# balance_warehouse_1: plant_1_warehouse_1 + plant_2_warehouse_1
#  + plant_3_warehouse_1 + plant_4_warehouse_1 + plant_5_warehouse_1
#  + plant_6_warehouse_1 - warehouse_1_hospital_1 - warehouse_1_hospital_10
#  - warehouse_1_hospital_2 - warehouse_1_hospital_3 - warehouse_1_hospital_4
#  - warehouse_1_hospital_5 - warehouse_1_hospital_6 - warehouse_1_hospital_7
#  - warehouse_1_hospital_8 - warehouse_1_hospital_9 = 0
#
# total_vaccines: warehouse_1_hospital_1 + warehouse_1_hospital_10
#  + warehouse_1_hospital_2 + warehouse_1_hospital_3 + warehouse_1_hospital_4
#  + warehouse_1_hospital_5 + warehouse_1_hospital_6 + warehouse_1_hospital_7
#  + warehouse_1_hospital_8 + warehouse_1_hospital_9 + warehouse_2_hospital_1
#  + warehouse_2_hospital_10 + warehouse_2_hospital_2 + warehouse_2_hospital_3
#  + warehouse_2_hospital_4 + warehouse_2_hospital_5 + warehouse_2_hospital_6
#  + warehouse_2_hospital_7 + warehouse_2_hospital_8 + warehouse_2_hospital_9
#  + warehouse_3_hospital_1 + warehouse_3_hospital_10 + warehouse_3_hospital_2
#  + warehouse_3_hospital_3 + warehouse_3_hospital_4 + warehouse_3_hospital_5
#  + warehouse_3_hospital_6 + warehouse_3_hospital_7 + warehouse_3_hospital_8
#  + warehouse_3_hospital_9 + warehouse_4_hospital_1 + warehouse_4_hospital_10
#  + warehouse_4_hospital_2 + warehouse_4_hospital_3 + warehouse_4_hospital_4
#  + warehouse_4_hospital_5 + warehouse_4_hospital_6 + warehouse_4_hospital_7
#  + warehouse_4_hospital_8 + warehouse_4_hospital_9 + warehouse_5_hospital_1
#  + warehouse_5_hospital_10 + warehouse_5_hospital_2 + warehouse_5_hospital_3
#  + warehouse_5_hospital_4 + warehouse_5_hospital_5 + warehouse_5_hospital_6
#  + warehouse_5_hospital_7 + warehouse_5_hospital_8 + warehouse_5_hospital_9
#  + warehouse_6_hospital_1 + warehouse_6_hospital_10 + warehouse_6_hospital_2
#  + warehouse_6_hospital_3 + warehouse_6_hospital_4 + warehouse_6_hospital_5
#  + warehouse_6_hospital_6 + warehouse_6_hospital_7 + warehouse_6_hospital_8
#  + warehouse_6_hospital_9 + warehouse_7_hospital_1 + warehouse_7_hospital_10
#  + warehouse_7_hospital_2 + warehouse_7_hospital_3 + warehouse_7_hospital_4
#  + warehouse_7_hospital_5 + warehouse_7_hospital_6 + warehouse_7_hospital_7
#  + warehouse_7_hospital_8 + warehouse_7_hospital_9 + warehouse_8_hospital_1
#  + warehouse_8_hospital_10 + warehouse_8_hospital_2 + warehouse_8_hospital_3
#  + warehouse_8_hospital_4 + warehouse_8_hospital_5 + warehouse_8_hospital_6
#  + warehouse_8_hospital_7 + warehouse_8_hospital_8 + warehouse_8_hospital_9
#  = 650
#
# hospital_demand_hospital_2: warehouse_1_hospital_2 + warehouse_2_hospital_2
#  + warehouse_3_hospital_2 + warehouse_4_hospital_2 + warehouse_5_hospital_2
#  + warehouse_6_hospital_2 + warehouse_7_hospital_2 + warehouse_8_hospital_2
#  <= 40
#
# hospital_demand_hospital_10: warehouse_1_hospital_10 + warehouse_2_hospital_10
#  + warehouse_3_hospital_10 + warehouse_4_hospital_10 + warehouse_5_hospital_10
#  + warehouse_6_hospital_10 + warehouse_7_hospital_10 + warehouse_8_hospital_10
#  <= 70
#
# hospital_demand_hospital_6: warehouse_1_hospital_6 + warehouse_2_hospital_6
#  + warehouse_3_hospital_6 + warehouse_4_hospital_6 + warehouse_5_hospital_6
#  + warehouse_6_hospital_6 + warehouse_7_hospital_6 + warehouse_8_hospital_6
#  <= 90
#
# hospital_demand_hospital_1: warehouse_1_hospital_1 + warehouse_2_hospital_1
#  + warehouse_3_hospital_1 + warehouse_4_hospital_1 + warehouse_5_hospital_1
#  + warehouse_6_hospital_1 + warehouse_7_hospital_1 + warehouse_8_hospital_1
#  <= 50
#
# hospital_demand_hospital_4: warehouse_1_hospital_4 + warehouse_2_hospital_4
#  + warehouse_3_hospital_4 + warehouse_4_hospital_4 + warehouse_5_hospital_4
#  + warehouse_6_hospital_4 + warehouse_7_hospital_4 + warehouse_8_hospital_4
#  <= 120
#
# hospital_demand_hospital_7: warehouse_1_hospital_7 + warehouse_2_hospital_7
#  + warehouse_3_hospital_7 + warehouse_4_hospital_7 + warehouse_5_hospital_7
#  + warehouse_6_hospital_7 + warehouse_7_hospital_7 + warehouse_8_hospital_7
#  <= 100
#
# hospital_demand_hospital_5: warehouse_1_hospital_5 + warehouse_2_hospital_5
#  + warehouse_3_hospital_5 + warehouse_4_hospital_5 + warehouse_5_hospital_5
#  + warehouse_6_hospital_5 + warehouse_7_hospital_5 + warehouse_8_hospital_5
#  <= 50
#
# hospital_demand_hospital_8: warehouse_1_hospital_8 + warehouse_2_hospital_8
#  + warehouse_3_hospital_8 + warehouse_4_hospital_8 + warehouse_5_hospital_8
#  + warehouse_6_hospital_8 + warehouse_7_hospital_8 + warehouse_8_hospital_8
#  <= 90
#
# hospital_demand_hospital_9: warehouse_1_hospital_9 + warehouse_2_hospital_9
#  + warehouse_3_hospital_9 + warehouse_4_hospital_9 + warehouse_5_hospital_9
#  + warehouse_6_hospital_9 + warehouse_7_hospital_9 + warehouse_8_hospital_9
#  <= 50
#
# hospital_demand_hospital_3: warehouse_1_hospital_3 + warehouse_2_hospital_3
#  + warehouse_3_hospital_3 + warehouse_4_hospital_3 + warehouse_5_hospital_3
#  + warehouse_6_hospital_3 + warehouse_7_hospital_3 + warehouse_8_hospital_3
#  <= 90
#
# warehouse_open_warehouse_8_to_hospital_2: - 100 open_warehouse_8
#  + warehouse_8_hospital_2 <= 0
#
# warehouse_open_warehouse_8_to_hospital_10: - 100 open_warehouse_8
#  + warehouse_8_hospital_10 <= 0
#
# warehouse_open_warehouse_8_to_hospital_6: - 100 open_warehouse_8
#  + warehouse_8_hospital_6 <= 0
#
# warehouse_open_warehouse_8_to_hospital_1: - 100 open_warehouse_8
#  + warehouse_8_hospital_1 <= 0
#
# warehouse_open_warehouse_8_to_hospital_4: - 100 open_warehouse_8
#  + warehouse_8_hospital_4 <= 0
#
# warehouse_open_warehouse_8_to_hospital_7: - 100 open_warehouse_8
#  + warehouse_8_hospital_7 <= 0
#
# warehouse_open_warehouse_8_to_hospital_5: - 100 open_warehouse_8
#  + warehouse_8_hospital_5 <= 0
#
# warehouse_open_warehouse_8_to_hospital_8: - 100 open_warehouse_8
#  + warehouse_8_hospital_8 <= 0
#
# warehouse_open_warehouse_8_to_hospital_9: - 100 open_warehouse_8
#  + warehouse_8_hospital_9 <= 0
#
# warehouse_open_warehouse_8_to_hospital_3: - 100 open_warehouse_8
#  + warehouse_8_hospital_3 <= 0
#
# warehouse_open_warehouse_5_to_hospital_2: - 80 open_warehouse_5
#  + warehouse_5_hospital_2 <= 0
#
# warehouse_open_warehouse_5_to_hospital_10: - 80 open_warehouse_5
#  + warehouse_5_hospital_10 <= 0
#
# warehouse_open_warehouse_5_to_hospital_6: - 80 open_warehouse_5
#  + warehouse_5_hospital_6 <= 0
#
# warehouse_open_warehouse_5_to_hospital_1: - 80 open_warehouse_5
#  + warehouse_5_hospital_1 <= 0
#
# warehouse_open_warehouse_5_to_hospital_4: - 80 open_warehouse_5
#  + warehouse_5_hospital_4 <= 0
#
# warehouse_open_warehouse_5_to_hospital_7: - 80 open_warehouse_5
#  + warehouse_5_hospital_7 <= 0
#
# warehouse_open_warehouse_5_to_hospital_5: - 80 open_warehouse_5
#  + warehouse_5_hospital_5 <= 0
#
# warehouse_open_warehouse_5_to_hospital_8: - 80 open_warehouse_5
#  + warehouse_5_hospital_8 <= 0
#
# warehouse_open_warehouse_5_to_hospital_9: - 80 open_warehouse_5
#  + warehouse_5_hospital_9 <= 0
#
# warehouse_open_warehouse_5_to_hospital_3: - 80 open_warehouse_5
#  + warehouse_5_hospital_3 <= 0
#
# warehouse_open_warehouse_4_to_hospital_2: - 100 open_warehouse_4
#  + warehouse_4_hospital_2 <= 0
#
# warehouse_open_warehouse_4_to_hospital_10: - 100 open_warehouse_4
#  + warehouse_4_hospital_10 <= 0
#
# warehouse_open_warehouse_4_to_hospital_6: - 100 open_warehouse_4
#  + warehouse_4_hospital_6 <= 0
#
# warehouse_open_warehouse_4_to_hospital_1: - 100 open_warehouse_4
#  + warehouse_4_hospital_1 <= 0
#
# warehouse_open_warehouse_4_to_hospital_4: - 100 open_warehouse_4
#  + warehouse_4_hospital_4 <= 0
#
# warehouse_open_warehouse_4_to_hospital_7: - 100 open_warehouse_4
#  + warehouse_4_hospital_7 <= 0
#
# warehouse_open_warehouse_4_to_hospital_5: - 100 open_warehouse_4
#  + warehouse_4_hospital_5 <= 0
#
# warehouse_open_warehouse_4_to_hospital_8: - 100 open_warehouse_4
#  + warehouse_4_hospital_8 <= 0
#
# warehouse_open_warehouse_4_to_hospital_9: - 100 open_warehouse_4
#  + warehouse_4_hospital_9 <= 0
#
# warehouse_open_warehouse_4_to_hospital_3: - 100 open_warehouse_4
#  + warehouse_4_hospital_3 <= 0
#
# warehouse_open_warehouse_6_to_hospital_2: - 290 open_warehouse_6
#  + warehouse_6_hospital_2 <= 0
#
# warehouse_open_warehouse_6_to_hospital_10: - 290 open_warehouse_6
#  + warehouse_6_hospital_10 <= 0
#
# warehouse_open_warehouse_6_to_hospital_6: - 290 open_warehouse_6
#  + warehouse_6_hospital_6 <= 0
#
# warehouse_open_warehouse_6_to_hospital_1: - 290 open_warehouse_6
#  + warehouse_6_hospital_1 <= 0
#
# warehouse_open_warehouse_6_to_hospital_4: - 290 open_warehouse_6
#  + warehouse_6_hospital_4 <= 0
#
# warehouse_open_warehouse_6_to_hospital_7: - 290 open_warehouse_6
#  + warehouse_6_hospital_7 <= 0
#
# warehouse_open_warehouse_6_to_hospital_5: - 290 open_warehouse_6
#  + warehouse_6_hospital_5 <= 0
#
# warehouse_open_warehouse_6_to_hospital_8: - 290 open_warehouse_6
#  + warehouse_6_hospital_8 <= 0
#
# warehouse_open_warehouse_6_to_hospital_9: - 290 open_warehouse_6
#  + warehouse_6_hospital_9 <= 0
#
# warehouse_open_warehouse_6_to_hospital_3: - 290 open_warehouse_6
#  + warehouse_6_hospital_3 <= 0
#
# warehouse_open_warehouse_3_to_hospital_2: - 80 open_warehouse_3
#  + warehouse_3_hospital_2 <= 0
#
# warehouse_open_warehouse_3_to_hospital_10: - 80 open_warehouse_3
#  + warehouse_3_hospital_10 <= 0
#
# warehouse_open_warehouse_3_to_hospital_6: - 80 open_warehouse_3
#  + warehouse_3_hospital_6 <= 0
#
# warehouse_open_warehouse_3_to_hospital_1: - 80 open_warehouse_3
#  + warehouse_3_hospital_1 <= 0
#
# warehouse_open_warehouse_3_to_hospital_4: - 80 open_warehouse_3
#  + warehouse_3_hospital_4 <= 0
#
# warehouse_open_warehouse_3_to_hospital_7: - 80 open_warehouse_3
#  + warehouse_3_hospital_7 <= 0
#
# warehouse_open_warehouse_3_to_hospital_5: - 80 open_warehouse_3
#  + warehouse_3_hospital_5 <= 0
#
# warehouse_open_warehouse_3_to_hospital_8: - 80 open_warehouse_3
#  + warehouse_3_hospital_8 <= 0
#
# warehouse_open_warehouse_3_to_hospital_9: - 80 open_warehouse_3
#  + warehouse_3_hospital_9 <= 0
#
# warehouse_open_warehouse_3_to_hospital_3: - 80 open_warehouse_3
#  + warehouse_3_hospital_3 <= 0
#
# warehouse_open_warehouse_7_to_hospital_2: - 50 open_warehouse_7
#  + warehouse_7_hospital_2 <= 0
#
# warehouse_open_warehouse_7_to_hospital_10: - 50 open_warehouse_7
#  + warehouse_7_hospital_10 <= 0
#
# warehouse_open_warehouse_7_to_hospital_6: - 50 open_warehouse_7
#  + warehouse_7_hospital_6 <= 0
#
# warehouse_open_warehouse_7_to_hospital_1: - 50 open_warehouse_7
#  + warehouse_7_hospital_1 <= 0
#
# warehouse_open_warehouse_7_to_hospital_4: - 50 open_warehouse_7
#  + warehouse_7_hospital_4 <= 0
#
# warehouse_open_warehouse_7_to_hospital_7: - 50 open_warehouse_7
#  + warehouse_7_hospital_7 <= 0
#
# warehouse_open_warehouse_7_to_hospital_5: - 50 open_warehouse_7
#  + warehouse_7_hospital_5 <= 0
#
# warehouse_open_warehouse_7_to_hospital_8: - 50 open_warehouse_7
#  + warehouse_7_hospital_8 <= 0
#
# warehouse_open_warehouse_7_to_hospital_9: - 50 open_warehouse_7
#  + warehouse_7_hospital_9 <= 0
#
# warehouse_open_warehouse_7_to_hospital_3: - 50 open_warehouse_7
#  + warehouse_7_hospital_3 <= 0
#
# warehouse_open_warehouse_2_to_hospital_2: - 200 open_warehouse_2
#  + warehouse_2_hospital_2 <= 0
#
# warehouse_open_warehouse_2_to_hospital_10: - 200 open_warehouse_2
#  + warehouse_2_hospital_10 <= 0
#
# warehouse_open_warehouse_2_to_hospital_6: - 200 open_warehouse_2
#  + warehouse_2_hospital_6 <= 0
#
# warehouse_open_warehouse_2_to_hospital_1: - 200 open_warehouse_2
#  + warehouse_2_hospital_1 <= 0
#
# warehouse_open_warehouse_2_to_hospital_4: - 200 open_warehouse_2
#  + warehouse_2_hospital_4 <= 0
#
# warehouse_open_warehouse_2_to_hospital_7: - 200 open_warehouse_2
#  + warehouse_2_hospital_7 <= 0
#
# warehouse_open_warehouse_2_to_hospital_5: - 200 open_warehouse_2
#  + warehouse_2_hospital_5 <= 0
#
# warehouse_open_warehouse_2_to_hospital_8: - 200 open_warehouse_2
#  + warehouse_2_hospital_8 <= 0
#
# warehouse_open_warehouse_2_to_hospital_9: - 200 open_warehouse_2
#  + warehouse_2_hospital_9 <= 0
#
# warehouse_open_warehouse_2_to_hospital_3: - 200 open_warehouse_2
#  + warehouse_2_hospital_3 <= 0
#
# warehouse_open_warehouse_1_to_hospital_2: - 200 open_warehouse_1
#  + warehouse_1_hospital_2 <= 0
#
# warehouse_open_warehouse_1_to_hospital_10: - 200 open_warehouse_1
#  + warehouse_1_hospital_10 <= 0
#
# warehouse_open_warehouse_1_to_hospital_6: - 200 open_warehouse_1
#  + warehouse_1_hospital_6 <= 0
#
# warehouse_open_warehouse_1_to_hospital_1: - 200 open_warehouse_1
#  + warehouse_1_hospital_1 <= 0
#
# warehouse_open_warehouse_1_to_hospital_4: - 200 open_warehouse_1
#  + warehouse_1_hospital_4 <= 0
#
# warehouse_open_warehouse_1_to_hospital_7: - 200 open_warehouse_1
#  + warehouse_1_hospital_7 <= 0
#
# warehouse_open_warehouse_1_to_hospital_5: - 200 open_warehouse_1
#  + warehouse_1_hospital_5 <= 0
#
# warehouse_open_warehouse_1_to_hospital_8: - 200 open_warehouse_1
#  + warehouse_1_hospital_8 <= 0
#
# warehouse_open_warehouse_1_to_hospital_9: - 200 open_warehouse_1
#  + warehouse_1_hospital_9 <= 0
#
# warehouse_open_warehouse_1_to_hospital_3: - 200 open_warehouse_1
#  + warehouse_1_hospital_3 <= 0
#
# VARIABLES
# 0 <= open_warehouse_1 <= 1 Integer
# 0 <= open_warehouse_2 <= 1 Integer
# 0 <= open_warehouse_3 <= 1 Integer
# 0 <= open_warehouse_4 <= 1 Integer
# 0 <= open_warehouse_5 <= 1 Integer
# 0 <= open_warehouse_6 <= 1 Integer
# 0 <= open_warehouse_7 <= 1 Integer
# 0 <= open_warehouse_8 <= 1 Integer
# plant_1_warehouse_1 Continuous
# plant_1_warehouse_2 Continuous
# plant_1_warehouse_3 Continuous
# plant_1_warehouse_4 Continuous
# plant_1_warehouse_5 Continuous
# plant_1_warehouse_6 Continuous
# plant_1_warehouse_7 Continuous
# plant_1_warehouse_8 Continuous
# plant_2_warehouse_1 Continuous
# plant_2_warehouse_2 Continuous
# plant_2_warehouse_3 Continuous
# plant_2_warehouse_4 Continuous
# plant_2_warehouse_5 Continuous
# plant_2_warehouse_6 Continuous
# plant_2_warehouse_7 Continuous
# plant_2_warehouse_8 Continuous
# plant_3_warehouse_1 Continuous
# plant_3_warehouse_2 Continuous
# plant_3_warehouse_3 Continuous
# plant_3_warehouse_4 Continuous
# plant_3_warehouse_5 Continuous
# plant_3_warehouse_6 Continuous
# plant_3_warehouse_7 Continuous
# plant_3_warehouse_8 Continuous
# plant_4_warehouse_1 Continuous
# plant_4_warehouse_2 Continuous
# plant_4_warehouse_3 Continuous
# plant_4_warehouse_4 Continuous
# plant_4_warehouse_5 Continuous
# plant_4_warehouse_6 Continuous
# plant_4_warehouse_7 Continuous
# plant_4_warehouse_8 Continuous
# plant_5_warehouse_1 Continuous
# plant_5_warehouse_2 Continuous
# plant_5_warehouse_3 Continuous
# plant_5_warehouse_4 Continuous
# plant_5_warehouse_5 Continuous
# plant_5_warehouse_6 Continuous
# plant_5_warehouse_7 Continuous
# plant_5_warehouse_8 Continuous
# plant_6_warehouse_1 Continuous
# plant_6_warehouse_2 Continuous
# plant_6_warehouse_3 Continuous
# plant_6_warehouse_4 Continuous
# plant_6_warehouse_5 Continuous
# plant_6_warehouse_6 Continuous
# plant_6_warehouse_7 Continuous
# plant_6_warehouse_8 Continuous
# warehouse_1_hospital_1 Continuous
# warehouse_1_hospital_10 Continuous
# warehouse_1_hospital_2 Continuous
# warehouse_1_hospital_3 Continuous
# warehouse_1_hospital_4 Continuous
# warehouse_1_hospital_5 Continuous
# warehouse_1_hospital_6 Continuous
# warehouse_1_hospital_7 Continuous
# warehouse_1_hospital_8 Continuous
# warehouse_1_hospital_9 Continuous
# warehouse_2_hospital_1 Continuous
# warehouse_2_hospital_10 Continuous
# warehouse_2_hospital_2 Continuous
# warehouse_2_hospital_3 Continuous
# warehouse_2_hospital_4 Continuous
# warehouse_2_hospital_5 Continuous
# warehouse_2_hospital_6 Continuous
# warehouse_2_hospital_7 Continuous
# warehouse_2_hospital_8 Continuous
# warehouse_2_hospital_9 Continuous
# warehouse_3_hospital_1 Continuous
# warehouse_3_hospital_10 Continuous
# warehouse_3_hospital_2 Continuous
# warehouse_3_hospital_3 Continuous
# warehouse_3_hospital_4 Continuous
# warehouse_3_hospital_5 Continuous
# warehouse_3_hospital_6 Continuous
# warehouse_3_hospital_7 Continuous
# warehouse_3_hospital_8 Continuous
# warehouse_3_hospital_9 Continuous
# warehouse_4_hospital_1 Continuous
# warehouse_4_hospital_10 Continuous
# warehouse_4_hospital_2 Continuous
# warehouse_4_hospital_3 Continuous
# warehouse_4_hospital_4 Continuous
# warehouse_4_hospital_5 Continuous
# warehouse_4_hospital_6 Continuous
# warehouse_4_hospital_7 Continuous
# warehouse_4_hospital_8 Continuous
# warehouse_4_hospital_9 Continuous
# warehouse_5_hospital_1 Continuous
# warehouse_5_hospital_10 Continuous
# warehouse_5_hospital_2 Continuous
# warehouse_5_hospital_3 Continuous
# warehouse_5_hospital_4 Continuous
# warehouse_5_hospital_5 Continuous
# warehouse_5_hospital_6 Continuous
# warehouse_5_hospital_7 Continuous
# warehouse_5_hospital_8 Continuous
# warehouse_5_hospital_9 Continuous
# warehouse_6_hospital_1 Continuous
# warehouse_6_hospital_10 Continuous
# warehouse_6_hospital_2 Continuous
# warehouse_6_hospital_3 Continuous
# warehouse_6_hospital_4 Continuous
# warehouse_6_hospital_5 Continuous
# warehouse_6_hospital_6 Continuous
# warehouse_6_hospital_7 Continuous
# warehouse_6_hospital_8 Continuous
# warehouse_6_hospital_9 Continuous
# warehouse_7_hospital_1 Continuous
# warehouse_7_hospital_10 Continuous
# warehouse_7_hospital_2 Continuous
# warehouse_7_hospital_3 Continuous
# warehouse_7_hospital_4 Continuous
# warehouse_7_hospital_5 Continuous
# warehouse_7_hospital_6 Continuous
# warehouse_7_hospital_7 Continuous
# warehouse_7_hospital_8 Continuous
# warehouse_7_hospital_9 Continuous
# warehouse_8_hospital_1 Continuous
# warehouse_8_hospital_10 Continuous
# warehouse_8_hospital_2 Continuous
# warehouse_8_hospital_3 Continuous
# warehouse_8_hospital_4 Continuous
# warehouse_8_hospital_5 Continuous
# warehouse_8_hospital_6 Continuous
# warehouse_8_hospital_7 Continuous
# warehouse_8_hospital_8 Continuous
# warehouse_8_hospital_9 Continuous

# %% [markdown]
# <!-- END QUESTION -->
#
# **12. Solve your optimization model and print its status and the optimal objective function value.  The optimal objective function value is 117910.0**

# %%
model.solve()
print("Status:", pulp.LpStatus[model.status])
if (pulp.LpStatus[model.status] == 'Optimal'):
    print("Obj function value:", model.objective.value(), "\n")
# Out:
# Status: Optimal
# Obj function value: 93840.0

# %% [markdown]
# **13. Output the value of each of your variables at optimality.  Only print variables with non-zero value.**

# %%
for v in model.variables():
    if v.varValue > 0:
        print(v, v.varValue)
# Out:
# open_warehouse_1 1.0
# open_warehouse_2 1.0
# open_warehouse_3 1.0
# open_warehouse_4 1.0
# open_warehouse_6 1.0
# open_warehouse_7 1.0
# open_warehouse_8 1.0
# plant_1_warehouse_7 150.0
# plant_2_warehouse_1 60.0
# plant_2_warehouse_3 20.0
# plant_2_warehouse_6 60.0
# plant_3_warehouse_6 120.0
# plant_4_warehouse_1 40.0
# plant_4_warehouse_3 40.0
# plant_4_warehouse_8 40.0
# plant_5_warehouse_2 50.0
# plant_6_warehouse_4 70.0
# warehouse_1_hospital_4 100.0
# warehouse_2_hospital_8 50.0
# warehouse_3_hospital_2 40.0
# warehouse_3_hospital_4 20.0
# warehouse_4_hospital_10 70.0
# warehouse_6_hospital_1 50.0
# warehouse_6_hospital_3 30.0
# warehouse_6_hospital_5 50.0
# warehouse_6_hospital_7 50.0
# warehouse_7_hospital_3 50.0
# warehouse_7_hospital_6 50.0
# warehouse_7_hospital_7 50.0
# warehouse_8_hospital_8 40.0

# %% [markdown]
# **14. Use Python to loop through each Hospital, display the total vaccine supplied to each hospital, its demand, shorfall, and percent of demand met.**

# %%
for hospital in hospitals:
    name = hospital['name']
    demand = hospital['demand']
    constraint_name = f"hospital_demand_{name}"
    slack = model.constraints[constraint_name].slack
    supply = demand - slack
    percent_met = (supply / demand) * 100 if demand > 0 else 0
    print(f"{name:<20} {supply:10.2f} {demand:10.2f} {slack:12.2f} {percent_met:10.2f}%")
# Out:
# hospital_2                40.00      40.00        -0.00     100.00%
# hospital_10               70.00      70.00        -0.00     100.00%
# hospital_6                50.00      90.00        40.00      55.56%
# hospital_1                50.00      50.00        -0.00     100.00%
# hospital_4               120.00     120.00        -0.00     100.00%
# hospital_7               100.00     100.00        -0.00     100.00%
# hospital_5                50.00      50.00        -0.00     100.00%
# hospital_8                90.00      90.00        -0.00     100.00%
# hospital_9                 0.00      50.00        50.00       0.00%
# hospital_3                80.00      90.00        10.00      88.89%
